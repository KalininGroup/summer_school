# %% [markdown]
# <a href="https://colab.research.google.com/gist/allaslautina/856a630c7e3a808c568dab580b8548f9/test_py_env.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font size = "5"> **Test Python Environment** </font>
#
#
# <hr style="height:1px;border-top:4px solid #FF8200" />
#
#
#
# [Download](https://gist.githubusercontent.com/allaslautina/856a630c7e3a808c568dab580b8548f9/raw/a1cf58c40faa6e24da7d930af9df25732ab7b7c8/test_py_env.ipynb)
#
# [![OpenInColab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/gist/allaslautina/856a630c7e3a808c568dab580b8548f9/test_py_env.ipynb)
#
#
# part of
#
# <font size = "5"> **[ML-STEM workshop](https://kaliningroup.github.io/summer_school/)**</font>
#
# by Gerd Duscher, Spring 2026
# <br>
# Microscopy Facilities<br>
# Institute of Advanced Materials & Manufacturing<br>
# Materials Science & Engineering<br>
# The University of Tennessee, Knoxville

# %% [markdown]
# ## Load Packages
#
# First we need to load the libraries we want to use.
# Here we use:
# - numpy: numerical library
# - matplotlib: graphic library
#
# Both of these packages are provided by annaconda and are already installed in Google Colab.

# %%
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# Now we run the next code cell to plot a graph.

# %%
# Generate plotting values
t = np.linspace(0, 2*np.pi, 200)
x = 16 * np.sin(t)**3
y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

plt.figure()
plt.plot(x,y, color='red', linewidth=2)
plt.text(-23, 0,  'I', ha='center', va='center', fontsize=206)

plt.text(20,0, 'ML STEM',va='center', fontsize=206)
plt.gca().set_aspect('equal')

# %% [markdown]
# Who would have thought that the formula of love is based on trigonometry?

# %% [markdown]
# Try to run this in colab and you rown computer.
